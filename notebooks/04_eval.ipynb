# %% [markdown]
# # 04 - Eval
#
# Purpose: evaluate trained model checkpoints — compute STOI/PESQ/WER
# metrics (via `src/evaluation/`) and inspect reconstructed audio samples
# from `results/audio_samples/`.
